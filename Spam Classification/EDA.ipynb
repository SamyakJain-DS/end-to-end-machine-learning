# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/data_v2.csv')

# %%
data.shape
# Out:
# (5999, 2)

# %%
data['number_of_words'] = data['mail'].apply(lambda x: len(x.split()))
data['number_of_chars'] = data['mail'].apply(lambda x: len(x))

# %%
data[data['number_of_words'] < 10]
# Out:
#                                                    mail label  \
# 136                           8000  50000   23    click  spam
# 165   su1qt1juqu5uielork9stufusu9oog0kdqpuagugbmv3ig...  spam
# 176   q09qwsbevkqgtu9wsuvtifrpienelvincljjr0huie5pvy...  spam
# 211   sgvsccb3yw50zwquicbxzsbhcmugysaxncb5zwfyig9szc...  spam
# 232   sgvsccb3yw50zwquicbxzsbhcmugysaxncb5zwfyig9szc...  spam
# ...                                                 ...   ...
# 5833  url 20021010t0326590100new evid case murder br...   ham
# 5839  url 20021010t0326570100world latest warn next ...   ham
# 5842  url 20021010t0326540100arts curat despair shor...   ham
# 5846  url 20021010t0326530100business powergen yeste...   ham
# 5850  url 20021010t0326510100money govern admit mill...   ham
#
#       number_of_words  number_of_chars
# 136                 4               25
# 165                 1             1512
# 176                 1             1365
# 211                 1              894
# 232                 1              902
# ...               ...              ...
# 5833                9               74
# 5839                9               67
# 5842                7               70
# 5846                8               78
# 5850                9               68
#
# [200 rows x 4 columns]

# %%
data.iloc[176,0]
# Out:
# '...'

# %%
data[(data['number_of_words'] < 10) & (data['number_of_chars'] > 90)]['mail'].values
# Out:
# array(['...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        '...',
#        'r2v0igfjy2vzcyb0byb0agugbgfyz2vzdcbmcmvligfkdwx0ihnpdgugb24gdghlig5ldc4ncg0kahr0cdovl3d3dy5tewzyzwvhzhvsdhbhexnpdguuy29tl2zyzwvzaxrllmh0bwwncjm4njj5vvjqoc03otdoam9qnzy2mhhubfk5lty1mvbgwfiyotyzs2tbadytmzgya0tludqxn2w1mq',
#        '...',
#        '',
#        '...',
#        '...',
#        '...',
#        '...',
#        ' sfnet email sponsor bythinkgeekwelcom geek heaven mail',
#        'deathtospamdeathtospamdeathtospamthi sfnet email sponsor bythinkgeekwelcom geek heaven mail',
#        '...',
#        '...',
#        '...'],
#       dtype=object)

# %%
drop_index = data[(data['number_of_words'] < 10) & (data['number_of_chars'] > 90)].index

# %%
data = data.drop(index = drop_index).reset_index(drop=True)

# %%
drop_index2 = data[(data['number_of_words'] < 25) & (data['number_of_chars'] > 200)].index

# %%
data = data.drop(index = drop_index2).reset_index(drop=True)

# %%
data
# Out:
#                                                    mail label  \
# 0     greetings ! y receiv letter express interest r...  spam
# 1     tr save 70 life insurance spend to ? life quot...  spam
# 2     need safeti real 2002 might get one chanc  rea...  spam
# 3     1 fight risk cancer ! slim  guarante lose 1012...  spam
# 4     1 fight risk cancer ! slim  guarante lose 1012...  spam
# ...                                                 ...   ...
# 5950  from tmdanethistoryhtmlth first releas tmda ap...   ham
# 5951  justin mason wrote phil r lawrenc said  someth...   ham
# 5952  wed 11 sep 2002 vinc puzzella wrote ever sinc ...   ham
# 5953  craig hugh said   header reproduc full address...   ham
# 5954  follow razor debug sequenc show mail go 9295 b...   ham
#
#       number_of_words  number_of_chars
# 0                 241             1540
# 1                 105              611
# 2                 391             2348
# 3                  48              300
# 4                  41              237
# ...               ...              ...
# 5950              192             1264
# 5951              116              673
# 5952               91              667
# 5953               50              345
# 5954              915             7849
#
# [5955 rows x 4 columns]

# %%
data.groupby('label')['number_of_words'].mean().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
data.groupby('label')['number_of_chars'].mean().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
data['label'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='label'>

# %%
data['label'].value_counts()  # The data is quite imbalanced.
# Out:
# label
# ham     4309
# spam    1646
# Name: count, dtype: int64

# %%
data.drop(columns=['number_of_words','number_of_chars']).to_csv('datasets/data_v3.csv', index=False)
